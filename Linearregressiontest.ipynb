# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt
from LinearRegression import LinearRegression

# %%
X, y = datasets.make_regression(n_samples = 100, n_features = 1, random_state =4, noise = 20)

# %%
X_train, y_train, X_test, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1233)

# %%
fig = plt.figure(figsize=(8,6))
plt.scatter(X[:, 0], y, color="b", marker="o", s=30)
plt.show()

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 reg = LinearRegression()
# ----> 2 reg.fit(X_train, y_train)
#
# File ~/Desktop/scratch ML/LinearRegression.py:22, in LinearRegression.fit(self, X, y)
#      17 self.bias = 0
#      19 for _ in range(self.n_iters): #looping through the number of iterations
#      20
#      21     #we will use vectorizaton instead of calculating the y_pred for each point - it will help to predict the samples of all at the same time
# ---> 22     y_pred = np.dot(X, self.weights) + self.bias #main formula for that line
#      24     #gradient
#      25     dw = (1/n_samples) * np.dot(X, (y_pred-y)) #the dot thing also does the sum
#
# ValueError: shapes (80,1) and (80,) not aligned: 1 (dim 1) != 80 (dim 0)
